# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('grades.csv')
df.head(10)
# Out:
#    ID  Класс          Период  Алг и матанализ  Биол.  Вер и Стат  Геогр.  \
# 0   1   10.0     1 Полугодие              4.0    4.0         4.0     5.0
# 1   1   10.0     2 Полугодие              4.0    4.0         5.0     5.0
# 2   1   10.0             Год              4.0    4.0         5.0     5.0
# 3   1   11.0     1 Полугодие              4.0    4.0         4.0     5.0
# 4   1   11.0     2 Полугодие              NaN    NaN         NaN     NaN
# 5   1   11.0             Год              NaN    NaN         NaN     NaN
# 6   1    NaN  Средняя оценка              4.0    4.0         4.5     5.0
# 7   1    NaN    Итог. оценка              NaN    NaN         NaN     NaN
# 8   2   10.0     1 Полугодие              5.0    5.0         5.0     5.0
# 9   2   10.0     2 Полугодие              5.0    5.0         5.0     5.0
#
#    Геом.  Англ.яз  Инф.  ...  Обществ.  ОБиЗР  Практ. по матем.  \
# 0   4.00      5.0   NaN  ...      4.00    5.0               NaN
# 1   3.00      5.0   NaN  ...      4.00    5.0               NaN
# 2   4.00      5.0   NaN  ...      4.00    5.0               NaN
# 3   4.00      5.0   5.0  ...      5.00    5.0               NaN
# 4    NaN      NaN   NaN  ...       NaN    NaN               NaN
# 5    NaN      NaN   NaN  ...       NaN    NaN               NaN
# 6   3.75      5.0   5.0  ...      4.25    5.0               0.0
# 7    NaN      NaN   NaN  ...       NaN    NaN               NaN
# 8   5.00      5.0   NaN  ...      5.00    5.0               NaN
# 9   5.00      5.0   NaN  ...      5.00    5.0               NaN
#
#    Практ. по обществ.  Рус.яз.  Совр. литерат  Физика  Физ-ра  Фин.гр.  Химия
# 0                 5.0      4.0            5.0     4.0     5.0      NaN   4.00
# 1                 5.0      4.0            5.0     4.0     4.0      NaN   4.00
# 2                 5.0      4.0            5.0     4.0     5.0      NaN   4.00
# 3                 NaN      4.0            5.0     4.0     5.0      NaN   5.00
# 4                 NaN      NaN            NaN     NaN     5.0      NaN    NaN
# 5                 NaN      NaN            NaN     NaN     NaN      NaN    NaN
# 6                 5.0      4.0            5.0     4.0     4.8      0.0   4.25
# 7                 NaN      NaN            NaN     NaN     NaN      NaN    NaN
# 8                 5.0      5.0            5.0     5.0     5.0      NaN   5.00
# 9                 5.0      5.0            5.0     5.0     5.0      NaN   5.00
#
# [10 rows x 22 columns]

# %%
df.describe()
# Out:
#                ID       Класс  Алг и матанализ       Биол.  Вер и Стат  \
# count  184.000000  138.000000       115.000000  115.000000  115.000000
# mean    12.000000   10.500000         3.663043    4.260870    3.956522
# std      6.651349    0.501821         0.689078    0.488229    0.704980
# min      1.000000   10.000000         3.000000    3.000000    3.000000
# 25%      6.000000   10.000000         3.000000    4.000000    3.125000
# 50%     12.000000   10.500000         3.750000    4.000000    4.000000
# 75%     18.000000   11.000000         4.000000    4.750000    4.500000
# max     23.000000   11.000000         5.000000    5.000000    5.000000
#
#            Геогр.       Геом.     Англ.яз       Инф.        Ист.  ...  \
# count  115.000000  115.000000  115.000000  46.000000  115.000000  ...
# mean     4.673913    3.478261    4.380435   4.652174    4.152174  ...
# std      0.577515    0.656918    0.501476   0.481543    0.453659  ...
# min      3.000000    3.000000    3.000000   4.000000    3.000000  ...
# 25%      4.500000    3.000000    4.000000   4.000000    4.000000  ...
# 50%      5.000000    3.000000    4.000000   5.000000    4.000000  ...
# 75%      5.000000    4.000000    5.000000   5.000000    4.000000  ...
# max      5.000000    5.000000    5.000000   5.000000    5.000000  ...
#
#          Обществ.       ОБиЗР  Практ. по матем.  Практ. по обществ.  \
# count  115.000000  115.000000              23.0                92.0
# mean     4.130435    4.967391               0.0                 5.0
# std      0.439732    0.163975               0.0                 0.0
# min      3.000000    4.000000               0.0                 5.0
# 25%      4.000000    5.000000               0.0                 5.0
# 50%      4.000000    5.000000               0.0                 5.0
# 75%      4.000000    5.000000               0.0                 5.0
# max      5.000000    5.000000               0.0                 5.0
#
#           Рус.яз.  Совр. литерат      Физика      Физ-ра  Фин.гр.       Химия
# count  115.000000          115.0  115.000000  138.000000     23.0  115.000000
# mean     3.945652            5.0    4.108696    4.617391      0.0    4.543478
# std      0.650390            0.0    0.529948    0.464493      0.0    0.490324
# min      3.000000            5.0    3.000000    4.000000      0.0    3.000000
# 25%      3.500000            5.0    4.000000    4.000000      0.0    4.000000
# 50%      4.000000            5.0    4.000000    5.000000      0.0    4.750000
# 75%      4.000000            5.0    4.000000    5.000000      0.0    5.000000
# max      5.000000            5.0    5.000000    5.000000      0.0    5.000000
#
# [8 rows x 21 columns]

# %%
sns.histplot(df.drop(['ID', 'Класс'], axis=1))
# Out:
# <Axes: ylabel='Count'>

# %%
df_long = df.melt(
    id_vars=['ID', 'Класс', 'Период'], 
    value_vars=[
        'Алг и матанализ', 'Биол.', 'Вер и Стат', 'Геогр.', 'Геом.', 
        'Англ.яз', 'Инф.', 'Ист.', 'Лит-ра', 'Обществ.', 'ОБиЗР', 
        'Практ. по матем.', 'Практ. по обществ.', 'Рус.яз.', 
        'Совр. литерат', 'Физика', 'Физ-ра', 'Фин.гр.', 'Химия'
    ],
    var_name='Предмет',
    value_name='Оценка'
)

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(data=df_long, x='Предмет', y='Оценка')
plt.xticks(rotation=90)  # Поворот подписей предметов
plt.title('Распределение оценок по предметам')
# Out:
# Text(0.5, 1.0, 'Распределение оценок по предметам')

# %%
# Выбираем только числовые столбцы с оценками
subjects = [
    'Алг и матанализ', 'Биол.', 'Вер и Стат', 'Геом.', 
    'Физика', 'Химия', 'Инф.'
]

plt.figure(figsize=(12, 8))
sns.heatmap(
    df[subjects].corr(), 
    annot=True, 
    cmap='coolwarm'
).set(title='Корреляция между техническими предметами')
# Out:
# [Text(0.5, 1.0, 'Корреляция между техническими предметами')]

# %%
sns.lineplot(
    data=df.groupby('Период')['Химия'].mean().reset_index(), 
    x='Период', 
    y='Химия', 
    marker='o'
).set(title='Динамика оценок по химии')
# Out:
# [Text(0.5, 1.0, 'Динамика оценок по химии')]
