# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("tables/Сводная_ведомость_учета_успеваемости_класса.xlsx", header=2)
df.tail()
# Out:
#     Unnamed: 0 Unnamed: 1      Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 187        NaN         11     1 Полугодие          5          4          5
# 188        NaN        NaN     2 Полугодие        NaN        NaN        NaN
# 189        NaN        NaN             Год        NaN        NaN        NaN
# 190        NaN        NaN  Средняя оценка          5        4,5          5
# 191        NaN        NaN    Итог. оценка        NaN        NaN        NaN
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 12 Unnamed: 13  \
# 187          5          5          5          5  ...           5           5
# 188        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 189        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 190          5       4,75          5          5  ...           5           5
# 191        NaN        NaN        NaN        NaN  ...         NaN         NaN
#
#     Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 187         NaN         NaN           5           5           5           5
# 188         NaN         NaN         NaN         NaN         NaN           4
# 189         NaN         NaN         NaN         NaN         NaN         NaN
# 190           0           5           5           5           5         4,8
# 191         NaN         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 20 Unnamed: 21
# 187         NaN           5
# 188         NaN         NaN
# 189         NaN         NaN
# 190           0           5
# 191         NaN         NaN
#
# [5 rows x 22 columns]

# %%
# Определение столбцов
subjects = [
    "Алг и матанализ", "Биол.", "Вер и Стат", "Геогр.", "Геом.", 
    "Англ.яз", "Инф.", "Ист.", "Лит-ра", "Обществ.", "ОБиЗР", 
    "Практ. по матем.", "Практ. по обществ.", "Рус.яз.", "Совр. литерат", 
    "Физика", "Физ-ра", "Фин.гр.", "Химия"
]

# Создание уникальных ID для учеников
student_names = df[df.iloc[:, 0].str.contains("Ученик|Ученица", na=False)].iloc[:, 0]
student_ids = {name: i+1 for i, name in enumerate(student_names)}

# %%
# Сбор данных
data = []
current_id = 0
current_class = None

def row_to_float(row):
    grades = row[3:22].values
    grades = [str(x).replace(',', '.') for x in grades]
    grades = list(map(float, grades))
    return grades
    
for idx, row in df.iterrows():
    if "Ученик" in str(row.iloc[0]) or "Ученица" in str(row.iloc[0]):
        current_name = row.iloc[0]
        current_id = student_ids[current_name]
    if pd.notna(row.iloc[1]) and (row.iloc[1] in [10, 11] or str(row.iloc[1]).isdigit()):
        current_class = int(row.iloc[1])
    if isinstance(row.iloc[2], str):
        if "Полугодие" in row.iloc[2] or "Год" in row.iloc[2]:
            period = row.iloc[2]
            grades = row_to_float(row)
            grades = list(map(float, grades))
            data.append([current_id, current_class, period] + list(grades))
        elif "Средняя оценка" in row.iloc[2]:
            period = "Средняя оценка"
            grades = row_to_float(row)
            data.append([current_id, "", period] + list(grades))
        elif "Итог. оценка" in row.iloc[2]:
            period = "Итог. оценка"
            grades = row_to_float(row)
            data.append([current_id, "", period] + list(grades))

# %%
def clean_df(df):
    unness_columns = ['ID', 'Класс', 'Период', 'Физ-ра']
    subject_columns = [col for col in df.columns if col not in unness_columns]
    df_cleaned = df.dropna(how='all', subset=subject_columns)
    df_cleaned = df_cleaned.drop(columns=['Практ. по матем.', 'Фин.гр.'])
    df_cleaned = df_cleaned.drop(columns=['ID', 'Класс'])
    df_cleaned = df_cleaned.reset_index(drop=True)
    return df_cleaned

def save_csv(need_to_clear=True):
    result = pd.DataFrame(
        data,
        columns=["ID", "Класс", "Период"] + subjects
    )
    result = result.replace("", np.nan)
    if need_to_clear:
        df_cleaned = clean_df(result)
        df_cleaned.to_csv("tables/10-11_2023-2025.csv", index=False, encoding="utf-8-sig")
    else:
        result.to_csv("tables/10-11_2023-2025.csv", index=False, encoding="utf-8-sig")
save_csv()
# Out:
# C:\Users\motve\AppData\Local\Temp\ipykernel_12956\2960196573.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   result = result.replace("", np.nan)
