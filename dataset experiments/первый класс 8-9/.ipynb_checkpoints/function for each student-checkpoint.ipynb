# %%
import pandas as pd
import numpy as np

# %%
df_8 = pd.read_excel("Отчет_по_месяцам_8А_2023_2024.xlsx", header=1)
df_8.head(15)
# Out:
#                                       Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0   Отчет об успеваемости и посещаемости ученика        NaN        NaN
# 1                                            NaN        NaN        NaN
# 2                                            NaN        NaN        NaN
# 3                         Учебный год: 2023/2024        NaN        NaN
# 4                                      Класс: 8А        NaN        NaN
# 5                 Период: с 01.09.23 по 31.05.24        NaN        NaN
# 6                                       Ученик 1        NaN        NaN
# 7                                            NaN        NaN        NaN
# 8                                        Предмет   Сентябрь        NaN
# 9                                            NaN          1          4
# 10                                       Алгебра        NaN        NaN
# 11                                      Биология        NaN        NaN
# 12                                     География        NaN        NaN
# 13                                     Геометрия        NaN        NaN
# 14                            Графический дизайн        NaN        NaN
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8  \
# 0         NaN        NaN        NaN        NaN        NaN         NaN
# 1         NaN        NaN        NaN        NaN        NaN         NaN
# 2         NaN        NaN        NaN        NaN        NaN         NaN
# 3         NaN        NaN        NaN        NaN        NaN         NaN
# 4         NaN        NaN        NaN        NaN        NaN         NaN
# 5         NaN        NaN        NaN        NaN        NaN         NaN
# 6         NaN        NaN        NaN        NaN        NaN         NaN
# 7         NaN        NaN        NaN        NaN        NaN         NaN
# 8         NaN        NaN        NaN        NaN        NaN         NaN
# 9           5          7          8         11         12        13.0
# 10        NaN        NaN        NaN        NaN        NaN         NaN
# 11          5        NaN          4        NaN          4         NaN
# 12        NaN        NaN        NaN        NaN        NaN         NaN
# 13        NaN        NaN        NaN        NaN          3         NaN
# 14        NaN        NaN        NaN        NaN        NaN         NaN
#
#    Unnamed: 9  ... Unnamed: 244 Unnamed: 245 Unnamed: 246 Unnamed: 247  \
# 0         NaN  ...          NaN          NaN          NaN          NaN
# 1         NaN  ...          NaN          NaN          NaN          NaN
# 2         NaN  ...          NaN          NaN          NaN          NaN
# 3         NaN  ...          NaN          NaN          NaN          NaN
# 4         NaN  ...          NaN          NaN          NaN          NaN
# 5         NaN  ...          NaN          NaN          NaN          NaN
# 6         NaN  ...          NaN          NaN          NaN          NaN
# 7         NaN  ...          NaN          NaN          NaN          NaN
# 8         NaN  ...          NaN          NaN          NaN          NaN
# 9          14  ...          NaN          NaN          NaN          NaN
# 10        NaN  ...          NaN          NaN          NaN          NaN
# 11        NaN  ...          NaN          NaN          NaN          NaN
# 12          5  ...          NaN          NaN          NaN          NaN
# 13        NaN  ...          NaN          NaN          NaN          NaN
# 14          2  ...          NaN          NaN          NaN          NaN
#
#    Unnamed: 248 Unnamed: 249 Unnamed: 250 Unnamed: 251 Unnamed: 252  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN          NaN
# 11          NaN          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN          NaN          NaN
# 13          NaN          NaN          NaN          NaN          NaN
# 14          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 253
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
#
# [15 rows x 254 columns]

# %%
def clean_df(df):
    words_to_exclude = ['Год', 'Класс', 'Период', 'год', 'Уважительная', 'Болезнь', 'Неуважительная', 'Опоздание']
    exclude_pattern = '|'.join(words_to_exclude)

    df_cleaned = df[~df.iloc[:, 0].str.contains(exclude_pattern, na=False)]
    df_cleaned = df_cleaned[~df_cleaned.iloc[:, 1].str.contains(exclude_pattern, na=False)]
    df_cleaned = df_cleaned.dropna(how='all')
    df_cleaned = df_cleaned.iloc[1:].reset_index(drop=True)

    return df_cleaned

# %%
df_8_clean = clean_df(df_8.copy())

# %%
df_8_clean.head(25)
# Out:
#                                Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                Ученик 1        NaN        NaN        NaN
# 1                                 Предмет   Сентябрь        NaN        NaN
# 2                                     NaN          1          4          5
# 3                                 Алгебра        NaN        NaN        NaN
# 4                                Биология        NaN        NaN          5
# 5                               География        NaN        NaN        NaN
# 6                               Геометрия        NaN        NaN        NaN
# 7                      Графический дизайн        NaN        NaN        NaN
# 8      Иностранный язык (Английский язык)          4        У 4        NaN
# 9                             Информатика        NaN        NaN        NaN
# 10                                История        NaN        NaN        NaN
# 11                             Литература        NaN          У        NaN
# 12                                 Музыка        NaN        NaN          5
# 13                         Обществознание        NaN          У        NaN
# 14  Основы безопасности жизнедеятельности        NaN        NaN        NaN
# 15                Разговоры о важном (ВД)        NaN          У        NaN
# 16            Россия - мои горизонты (ВД)        NaN        NaN        NaN
# 17                           Русский язык        NaN        NaN        NaN
# 18                       Смысловое чтение        NaN          У        NaN
# 19                        Технология 1 гр        NaN        NaN        NaN
# 20                        Технология 2 гр        NaN        NaN        NaN
# 21                                 Физика        NaN          У          3
# 22                    Физическая культура        NaN          У        NaN
# 23                                  Химия        NaN          У        NaN
# 24                               Ученик 2        NaN        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8 Unnamed: 9  ...  \
# 0         NaN        NaN        NaN        NaN         NaN        NaN  ...
# 1         NaN        NaN        NaN        NaN         NaN        NaN  ...
# 2           7          8         11         12        13.0         14  ...
# 3         NaN        NaN        NaN        NaN         NaN        NaN  ...
# 4         NaN          4        NaN          4         NaN        NaN  ...
# 5         NaN        NaN        NaN        NaN         NaN          5  ...
# 6         NaN        NaN        NaN          3         NaN        NaN  ...
# 7         NaN        NaN        NaN        NaN         NaN          2  ...
# 8           4        NaN        NaN        NaN         NaN          3  ...
# 9         NaN        NaN        NaN        NaN         NaN          5  ...
# 10        NaN          5        NaN        NaN         NaN        NaN  ...
# 11        NaN          4        NaN        NaN         NaN        NaN  ...
# 12        NaN        NaN        NaN        NaN         NaN        NaN  ...
# 13        NaN        NaN          5        NaN         NaN        NaN  ...
# 14        NaN          4        NaN        NaN         NaN        NaN  ...
# 15        NaN        NaN        NaN        NaN         NaN        NaN  ...
# 16        NaN        NaN        NaN        NaN         NaN        NaN  ...
# 17          3        NaN        NaN        NaN         NaN          2  ...
# 18        NaN        NaN          3        NaN         NaN        NaN  ...
# 19        NaN        NaN        NaN        NaN         NaN          4  ...
# 20        NaN        NaN        NaN        NaN         NaN        NaN  ...
# 21        NaN        NaN        NaN          2         NaN        NaN  ...
# 22        NaN        NaN        5/5        NaN         5.0        NaN  ...
# 23        NaN        NaN          4        NaN         NaN        NaN  ...
# 24        NaN        NaN        NaN        NaN         NaN        NaN  ...
#
#    Unnamed: 244 Unnamed: 245 Unnamed: 246 Unnamed: 247 Unnamed: 248  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN          NaN
# 11          NaN          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN          NaN          NaN
# 13          NaN          NaN          NaN          NaN          NaN
# 14          NaN          NaN          NaN          NaN          NaN
# 15          NaN          NaN          NaN          NaN          NaN
# 16          NaN          NaN          NaN          NaN          NaN
# 17          NaN          NaN          NaN          NaN          NaN
# 18          NaN          NaN          NaN          NaN          NaN
# 19          NaN          NaN          NaN          NaN          NaN
# 20          NaN          NaN          NaN          NaN          NaN
# 21          NaN          NaN          NaN          NaN          NaN
# 22          NaN          NaN          NaN          NaN          NaN
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 249 Unnamed: 250 Unnamed: 251 Unnamed: 252 Unnamed: 253
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN          NaN
# 11          NaN          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN          NaN          NaN
# 13          NaN          NaN          NaN          NaN          NaN
# 14          NaN          NaN          NaN          NaN          NaN
# 15          NaN          NaN          NaN          NaN          NaN
# 16          NaN          NaN          NaN          NaN          NaN
# 17          NaN          NaN          NaN          NaN          NaN
# 18          NaN          NaN          NaN          NaN          NaN
# 19          NaN          NaN          NaN          NaN          NaN
# 20          NaN          NaN          NaN          NaN          NaN
# 21          NaN          NaN          NaN          NaN          NaN
# 22          NaN          NaN          NaN          NaN          NaN
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
#
# [25 rows x 254 columns]

# %%
def create_students_dict(df):
    rows_per_student = 24
    student_data = {}
    # Итерируемся по датасету с шагом в 'rows_per_student'
    for i in range(0, len(df), rows_per_student):
        student_df_full = df.iloc[i:i + rows_per_student].copy().reset_index(drop=True)

        # Получаем имя ученика из первой строки
        student_name = student_df_full.iloc[0, 0]  # Предполагаем, что имя ученика в первом столбце

        # Устанавливаем корректные заголовки
        header_subject = student_df_full.iloc[1].fillna('')
        header_date = student_df_full.iloc[2].fillna('')

        new_columns = []
        for j in range(len(header_subject)):
            if header_subject[j] and header_date[j]:
                new_columns.append(f"{header_subject[j]}_{header_date[j]}")
            elif header_subject[j]:
                new_columns.append(header_subject[j])
            else:
                new_columns.append(header_date[j])

        student_df_full.columns = new_columns
        student_df_processed = student_df_full.iloc[3:].reset_index(drop=True)
        student_df_processed.rename(columns={student_df_processed.columns[0]: 'Предмет'}, inplace=True)

        # Ищем индекс столбца "Средняя оценка"
        try:
            last_valid_column_index = student_df_processed.columns.get_loc('Средняя оценка') + 1
            # Выбираем все столбцы до "Средняя оценка" включительно
            cleaned_student_df = student_df_processed.iloc[:, :last_valid_column_index].copy()
            student_data[student_name] = cleaned_student_df
        except KeyError:
            print(f"В данных ученика '{student_name}' не найден столбец 'Средняя оценка'.")
            student_data[student_name] = student_df_processed.copy() # Сохраняем весь DataFrame, если столбец не найден

    return student_data

student_dict = create_students_dict(df_8_clean)
stud1 = student_dict['Ученик 1']
# Out:
# C:\Users\motve\AppData\Local\Temp\ipykernel_22012\2465341332.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if header_subject[j] and header_date[j]:
# C:\Users\motve\AppData\Local\Temp\ipykernel_22012\2465341332.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif header_subject[j]:
# C:\Users\motve\AppData\Local\Temp\ipykernel_22012\2465341332.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   new_columns.append(header_subject[j])
# C:\Users\motve\AppData\Local\Temp\ipykernel_22012\2465341332.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   new_columns.append(f"{header_subject[j]}_{header_date[j]}")
# C:\Users\motve\AppData\Local\Temp\ipykernel_22012\2465341332.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   new_columns.append(header_date[j])

# %%
stud1
# Out:
#                                   Предмет Сентябрь_1    4    5    7    8   11  \
# 0                                 Алгебра        NaN  NaN  NaN  NaN  NaN  NaN
# 1                                Биология        NaN  NaN    5  NaN    4  NaN
# 2                               География        NaN  NaN  NaN  NaN  NaN  NaN
# 3                               Геометрия        NaN  NaN  NaN  NaN  NaN  NaN
# 4                      Графический дизайн        NaN  NaN  NaN  NaN  NaN  NaN
# 5      Иностранный язык (Английский язык)          4  У 4  NaN    4  NaN  NaN
# 6                             Информатика        NaN  NaN  NaN  NaN  NaN  NaN
# 7                                 История        NaN  NaN  NaN  NaN    5  NaN
# 8                              Литература        NaN    У  NaN  NaN    4  NaN
# 9                                  Музыка        NaN  NaN    5  NaN  NaN  NaN
# 10                         Обществознание        NaN    У  NaN  NaN  NaN    5
# 11  Основы безопасности жизнедеятельности        NaN  NaN  NaN  NaN    4  NaN
# 12                Разговоры о важном (ВД)        NaN    У  NaN  NaN  NaN  NaN
# 13            Россия - мои горизонты (ВД)        NaN  NaN  NaN  NaN  NaN  NaN
# 14                           Русский язык        NaN  NaN  NaN    3  NaN  NaN
# 15                       Смысловое чтение        NaN    У  NaN  NaN  NaN    3
# 16                        Технология 1 гр        NaN  NaN  NaN  NaN  NaN  NaN
# 17                        Технология 2 гр        NaN  NaN  NaN  NaN  NaN  NaN
# 18                                 Физика        NaN    У    3  NaN  NaN  NaN
# 19                    Физическая культура        NaN    У  NaN  NaN  NaN  5/5
# 20                                  Химия        NaN    У  NaN  NaN  NaN    4
#
#      12  13.0   14  ...   15   15   16   16   17   20   21   23   24  \
# 0   NaN   NaN  NaN  ...    Н    3  NaN  NaN  NaN  NaN  NaN  NaN    3
# 1     4   NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2   NaN   NaN    5  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3     3   NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN    3  NaN  NaN
# 4   NaN   NaN    2  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5   NaN   NaN    3  ...  NaN  NaN    4  NaN  NaN    4  NaN  NaN  NaN
# 6   NaN   NaN    5  ...  NaN  NaN    5  NaN  NaN  NaN  NaN    5  NaN
# 7   NaN   NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8   NaN   NaN  NaN  ...  NaN  NaN  NaN  NaN    5  NaN  NaN    4  NaN
# 9   NaN   NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10  NaN   NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 11  NaN   NaN  NaN  ...  NaN  NaN  NaN  NaN  5/5  NaN  NaN  NaN  NaN
# 12  NaN   NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13  NaN   NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 14  NaN   NaN    2  ...  NaN  NaN    3    3  NaN  NaN  NaN    4  NaN
# 15  NaN   NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN    4  NaN  NaN  NaN
# 16  NaN   NaN    4  ...  NaN  NaN    5  NaN  NaN  NaN  NaN  NaN  NaN
# 17  NaN   NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 18    2   NaN  NaN  ...  4/3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 19  NaN   5.0  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 20  NaN   NaN  NaN  ...  NaN  NaN    3  NaN  NaN  NaN  NaN  NaN  NaN
#
#    Средняя оценка
# 0        2.945946
# 1            3.76
# 2        4.266667
# 3        3.130435
# 4        3.652174
# 5            4.25
# 6        4.733333
# 7        4.538462
# 8        3.538462
# 9        4.388889
# 10       4.769231
# 11       4.307692
# 12              0
# 13              0
# 14       3.179487
# 15       3.631579
# 16            4.4
# 17              0
# 18       3.142857
# 19       4.529412
# 20            3.5
#
# [21 rows x 223 columns]
